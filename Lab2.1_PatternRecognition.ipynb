# %%
from numpy import genfromtxt

product_data = genfromtxt('/kaggle/input/most-streamed-songs-all-time/Streams.csv', delimiter='\t')

print(product_data)

import pandas as pd

sample_df = pd.read_csv('/kaggle/input/most-streamed-songs-all-time/Streams.csv', delimiter=',' , header=None)

sample_df.head()

sample_df.to_csv('Step9.csv')
# Out:
# [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan]
